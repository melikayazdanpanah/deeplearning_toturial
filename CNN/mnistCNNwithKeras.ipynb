# %% [markdown]
# convolution layers: Conv2D
# Pooling layers : MaxPooling2D
# one flatten layer
# one dense layer for extract features
# one softmax layer for classification

# %%
import tensorflow as tf
from keras.datasets import mnist

(train_images , y_train),(test_images, y_test)= mnist.load_data()
x_train = train_images.reshape(60000,28,28,1)/ 255
x_test = test_images.reshape(10000,28,28,1)/ 255
# Out:
# 2024-08-05 22:55:39.739157: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-05 22:55:39.747144: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-05 22:55:39.817955: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-05 22:55:39.902016: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 22:55:39.969201: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 22:55:39.986329: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-05 22:55:40.108838: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-05 22:55:41.075454: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow as tf
# ----> 2 from keras.datasets import mnist
#       4 (train_images , y_train),(test_images, y_test)= mnist.load_data()
#       5 x_train = train_images.reshape(60000,28,28,1)/ 255
#
# File ~/deepshahab/learn/deeplearning_toturial/CNN/keras.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.export.export_lib import TFSMLayer
#       8 from keras.src.layers import deserialize
#       9 from keras.src.layers import serialize
#
# ModuleNotFoundError: No module named 'keras.src'; 'keras' is not a package

# %%
import tensorflow as tf
from keras.src.models.sequential import Sequential
from keras.src.layers.core.dense import Dense
from keras.src.layers.convolutional.conv2d import Conv2D 
from keras.src.layers.activations.relu import ReLU
from keras.src.layers.activations.softmax import Softmax
from keras.src.layers.pooling.max_pooling2d import MaxPooling2D
from keras.src.layers.reshaping.flatten import Flatten

model = Sequential()
model.add(Conv2D(32,(3,3), activation ='relu', input_shape =(28,28,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3) ,activation ='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128, activation ='relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import tensorflow as tf
# ----> 2 from keras.src.models.sequential import Sequential
#       3 from keras.src.layers.core.dense import Dense
#       4 from keras.src.layers.convolutional.conv2d import Conv2D
#
# File ~/deepshahab/learn/deeplearning_toturial/CNN/keras.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.export.export_lib import TFSMLayer
#       8 from keras.src.layers import deserialize
#       9 from keras.src.layers import serialize
#
# ModuleNotFoundError: No module named 'keras.src'; 'keras' is not a package

# %%
model.compile(optimizer='adam',loss = 'sparse_categorical_crossentropy',metrics =['accuracy'])
model.summary(line_length=80)
